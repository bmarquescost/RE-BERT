# %% [markdown]
# # Training multiple RE-BERT: one for each APP review train dataset

# %% [markdown]
# In this new stage of the project, we are interest at the relationships of each 'category' inside the set of apps
# Therefore, we will use an ensemble of RE-BERT models based and trained on each app, applying such mechanism based on pre-trained models on a sub-group of app train data

# %%
# !git clone https://github.com/adailtonaraujo/RE-BERT.git
# Out:
# Cloning into 'RE-BERT'...

# %%
# !move RE-BERT/* .
# Out:
# J� existe um arquivo com o mesmo nome
# ou o arquivo n�o pode ser encontrado.

# %%
# !pip install -r RE-BERT/requirements.txt
# Out:
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1309 sha256=65bbfa4212a5ad8b2eb0d8ed38155ca0d24df5d7542563d58f8a18e475b3fa14
#   Stored in directory: c:\users\bm\appdata\local\pip\cache\wheels\22\0b\40\fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built sklearn
# ...

# %% [markdown]
# Training each model with it correspondent train app review data

# %%
# !python train.py --dataset eBay         --train_file dataset_train/train_Evernote.txt
# !python train.py --dataset Evernote     --train_file dataset_train/train_Evernote.txt
# !python train.py --dataset Facebook     --train_file dataset_train/train_Facebook.txt
# !python train.py --dataset Netflix      --train_file dataset_train/train_Netflix.txt
# !python train.py --dataset PhotoEditor  --train_file dataset_train/train_PhotoEditor.txt
# !python train.py --dataset Spotify      --train_file dataset_train/train_Spotify.txt
# !python train.py --dataset Twitter      --train_file dataset_train/train_Twitter.txt
# !python train.py --dataset WhatsApp     --train_file dataset_train/train_WhatsApp.txt

# %% [markdown]
# ## Testing one of the trained models

# %% [markdown]
# Testing one model pre-trained on single app, such as Twitter reviews, on another set of data, containing Evernote reviews

# %%
# !python extract.py --test_file datasets_iob/test_data_Twitter.txt --classifier_model_file trained_models/RE_BERT_Evernote_iob_epoch_1.model --output_file Twitter_extracted_reqs.txt
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# loading model RE_BERT ...
# Test Size: 183
# Extract software requirements candidates:   0% 0/183 [00:00<?, ?it/s]extract.py:72: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   t_inputs = [torch.tensor([data[col]], device=self.opt.device) for col in self.opt.inputs_cols]
# Extract software requirements candidates: 100% 183/183 [01:36<00:00,  1.90it/s]
# Extracted software requirements --> Twitter_extracted_reqs.txt

# %%
reviews_test = open('datasets_iob/test_data_Twitter.txt', 'r').readlines()
reqs_extracted = open('Twitter_extracted_reqs.txt', 'r').readlines()
reqs_labeled = open('datasets_iob/test_label_Twitter.txt', 'r').readlines()

# %%
import pandas as pd

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

df = pd.DataFrame()
df['review'] = reviews_test
df['labeled (humans)'] = reqs_labeled
df['extracted (re-bert)'] = reqs_extracted
df = df.replace('\n',' ', regex=True)
df
# Out:
#                                                                                                                                                                                        review  ...                                                          extracted (re-bert)
# 0                                                                                                                                                        Its ruining the overall experience    ...                                                  ruining;overall experience
# 1                                                                                                                                                                   Everything else is fine    ...
# ...
